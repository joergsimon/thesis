# %% [markdown]
# # Raw Time Series
#
# This notbeooks explores the nature of the timeseries in the data.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pickle
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import gestureanalysis.image_utils as iutils
import gestureanalysis.generate_channel_images as gci
from gestureanalysis.constants import Constants

# %%
base_path = "/home/ubuntu/thesis/gesture-analysis/data/"
base_path_raw = base_path+"raw/all"
stats_added_path_pickl = base_path+"transformed/stats_added/all/raw_stats-added-all.pkl"

# %%
# check working directory and adopt if needed
import os
os.getcwd()
# Out:
# '/home/ubuntu/thesis/gesture-analysis/scripts'

# %%
# in case you need to reload, and know it exists:
with open( stats_added_path_pickl, "rb" ) as users_pickle_file:
    users = pickle.load(users_pickle_file)

# %%
# correct corrupted labels
print(users.keys())
print('num users: ', len(users.keys()))
# Out:
# dict_keys(['AB73', 'AE30', 'AF82', 'AL29', 'AW18', 'CB23', 'CB24', 'CF58', 'DG12', 'DH42', 'DL24', 'JL61', 'JQ28', 'JS52', 'MF20', 'MS55', 'PC29', 'PM32', 'PS42', 'RR45', 'RW32', 'SF1', 'YW13'])
# num users:  23

# %%
usernames = users.keys()
gestures = users['AB73']['label'][0]['data']['gesture'].unique()

# %%
ud_helper = iutils.UserDataHelper(list(usernames), gestures, Constants().raw_headers)

# %%
plt.close('all')
callback, skippable = gci.generate_visualize_all_channel_user_gesture_combinations_callback(users, True)
skippable.mute()
ud_helper.iterate_gestures_of_users(callback)
skippable.report()
# Out:
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='gestures', max=31, style=ProgressStyle(description_width='ini…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='gestures', max=31, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='gestures', max=31, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='gestures', max=31, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='gestures', max=31, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='gestures', max=31, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='gestures', max=31, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='gestures', max=31, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='gestures', max=31, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='gestures', max=31, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='gestures', max=31, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='gestures', max=31, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='gestures', max=31, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='gestures', max=31, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='gestures', max=31, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='gestures', max=31, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='gestures', max=31, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='gestures', max=31, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='gestures', max=31, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='gestures', max=31, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='gestures', max=31, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='gestures', max=31, style=ProgressStyle(description_width='ini…
# skipped #682 image generations

# %%
ud_helper.display_random_generated_images(3,1,2)

# %%
ud_helper.display_random_generated_images(10,2,10)

# %%
collector = iutils.AllUsersCollector()
callback, skippable = gci.generate_visualize_all_channel_gesture_combinations_using_all_users_callback(
    users, collector, True)
skippable.mute()
ud_helper.iterate_users_of_gestures(callback)
template = gci.ChannelVisTemplate()
print(collector.current_gesture)
path = iutils.generate_img_base_path('all_users', collector.current_gesture, tqdm.tqdm_notebook([]))
template.visualize_gesture(path, collector.current_gesture, collector.instances_of_all_users, 
                           collector.groups_of_all_users, skippable)
skippable.report()
# Out:
# HBox(children=(IntProgress(value=0, description='gestures', max=31, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# (2) Two
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-53a0926b0eb1> in <module>
#       6 template = gci.ChannelVisTemplate()
#       7 print(collector.current_gesture)
# ----> 8 path = iutils.generate_img_base_path('all_users', collector.current_gesture, tqdm.tqdm_notebook([]))
#       9 template.visualize_gesture(path, collector.current_gesture, collector.instances_of_all_users,
#      10                            collector.groups_of_all_users, skippable)
#
# NameError: name 'tqdm' is not defined

# %%
channel1 = '0_Thumb_base'
channel2 = '58_Wrist_Gyro_Y'
gesture = 'Calling'

f, axarr = plt.subplots(1, 2, figsize=(20, 10))

axarr[0].set_title(f'{gesture} / {channel1}')
path = f'../figures/raw/all_users/{gesture}/{channel1}.png'
a = mpimg.imread(path)
axarr[0].imshow(a)

axarr[1].set_title(f'{gesture} / {channel2}')
path = f'../figures/raw/all_users/{gesture}/{channel2}.png'
a = mpimg.imread(path)
axarr[1].imshow(a)

plt.show()

# %%
collector = iutils.AllUsersCollector()
callback, skippable = gci.generate_visualize_all_channel_gesture_combinations_using_all_users_timealigned_callback(
    users, collector, True)
skippable.mute()
ud_helper.iterate_users_of_gestures(callback)
template = gci.ChannelVisTemplate()
path = iutils.generate_img_base_path('all_users_timealigned', collector.current_gesture, tqdm.tqdm_notebook([]))
template.visualize_gesture(path, collector.current_gesture, collector.instances_of_all_users, 
                           collector.groups_of_all_users, skippable)
skippable.report()
# Out:
# HBox(children=(IntProgress(value=0, description='gestures', max=31, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# HBox(children=(IntProgress(value=0, description='users', max=23, style=ProgressStyle(description_width='initia…
# skipping userAE30
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-0b881139d640> in <module>
#       5 ud_helper.iterate_users_of_gestures(callback)
#       6 template = gci.ChannelVisTemplate()
# ----> 7 path = iutils.generate_img_base_path('all_users_timealigned', collector.current_gesture, tqdm.tqdm_notebook([]))
#       8 template.visualize_gesture(path, collector.current_gesture, collector.instances_of_all_users,
#       9                            collector.groups_of_all_users, skippable)
#
# NameError: name 'tqdm' is not defined

# %%
# usually we take the same channels and gesture as the first grid
#channel1 = '19_Finger_1_Accel_Y'
#channel2 = '37_Finger_4_Accel_Y'
#gesture = 'Knocking'

f, axarr = plt.subplots(1, 2, figsize=(20, 10))

axarr[0].set_title(f'{gesture} / {channel1}')
path = f'../figures/raw/all_users_timealigned/{gesture}/{channel1}.png'
a = mpimg.imread(path)
axarr[0].imshow(a)

axarr[1].set_title(f'{gesture} / {channel2}')
path = f'../figures/raw/all_users_timealigned/{gesture}/{channel2}.png'
a = mpimg.imread(path)
axarr[1].imshow(a)

plt.show()

# %%
channel = '37_Finger_4_Accel_Y'
gesture1 = 'Knocking'
gesture2 = 'Waving'
gesture3 = 'Thumbs up'
gesture4 = 'Shoot'

f, axarr = plt.subplots(2, 2, figsize=(20, 10))

axarr[0, 0].set_title(f'{gesture1} / {channel}')
path = f'../figures/raw/all_users_timealigned/{gesture1}/{channel}.png'
a = mpimg.imread(path)
axarr[0, 0].imshow(a)

axarr[0, 1].set_title(f'{gesture2} / {channel}')
path = f'../figures/raw/all_users_timealigned/{gesture2}/{channel}.png'
a = mpimg.imread(path)
axarr[0, 1].imshow(a)

axarr[1, 0].set_title(f'{gesture3} / {channel}')
path = f'../figures/raw/all_users_timealigned/{gesture3}/{channel}.png'
a = mpimg.imread(path)
axarr[1, 0].imshow(a)

axarr[1, 1].set_title(f'{gesture4} / {channel}')
path = f'../figures/raw/all_users_timealigned/{gesture4}/{channel}.png'
a = mpimg.imread(path)
axarr[1, 1].imshow(a)

plt.show()
